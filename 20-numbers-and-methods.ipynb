# %% [markdown]
# # Integer Numbers and Methods

# %%
[i for i in dir(3) if not i.startswith('_')]
# Out:
# ['as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
number = 10
number.bit_length()
# Out:
# 4

# %%
len(bin(2)[2:]) == (2).bit_length()
# Out:
# True

# %%
type(10.)
# Out:
# float

# %%
[i for i in dir(float) if  not i.startswith("_")]
# Out:
# ['as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
number = 4.5
number.as_integer_ratio()
# Out:
# (9, 2)

# %%
number = 7.8
number.as_integer_ratio()
# Out:
# (8782019273372467, 1125899906842624)

# %%
(12.0).is_integer()
# Out:
# True

# %%
12.5.is_integer()
# Out:
# False

# %%
[i for i in dir(complex) if not i.startswith('_')]
# Out:
# ['conjugate', 'imag', 'real']

# %%
c = 12 + 4j
c.imag
# Out:
# 4.0

# %%
c.real
# Out:
# 12.0
