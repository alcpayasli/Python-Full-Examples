# %%
obj = "Python programming"

# %%
print(*obj, sep = ".")
# Out:
# P.y.t.h.o.n. .p.r.o.g.r.a.m.m.i.n.g

# %%
obj2 = "123456789"
for i in obj2:
    print(int(i)**2, end = "/")
# Out:
# 1/4/9/16/25/36/49/64/81/

# %%
word = "Hello World"
print(word[0])
print(word[1])
print(word[4])
print(word[len(word)-1])
print(word[-1])
print(word[-2])
print(word[-11])
# Out:
# H
# e
# o
# d
# d
# l
# H

# %%
for i in range(len(word)):
    print(word[i])
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
name = input("What's your name:")
for i in range(len(name)):
    print("{}.letter: {}".format(i+1, name[i]))
# Out:
# What's your name: Python
# 1.letter: P
# 2.letter: y
# 3.letter: t
# 4.letter: h
# 5.letter: o
# 6.letter: n

# %%
obj = "Hello world"
print(obj[3:8])
print(obj[0:4])
print(obj[:4])
# Out:
# lo wo
# Hell
# Hell

# %%
site1 = "www.google.com"
site2 = "www.kaggle.com"
site3 = 'www.github.com'
for sit in site1, site2, site3:
    print(sit[4:-4])
# Out:
# google
# kaggle
# github

# %%
sent1 = "Hello world!"
sent2 = "My name is Nobody!"
for sent in sent1, sent2:
    print(sent[:-1] + ".")
# Out:
# Hello world.
# My name is Nobody.

# %%
obj = "Hello World"
print(obj[::-1])
print(obj[::2])
print(obj[::-2])
# Out:
# dlroW olleH
# HloWrd
# drWolH

# %%
reversed(obj)

# %%
print(*reversed(obj))
# Out:
# d l r o W   o l l e H

# %%
for let in reversed(obj):
    print(let, end = "")
# Out:
# dlroW olleH

# %%
print(*reversed(obj), sep = "")
# Out:
# dlroW olleH

# %%
sorted("Python")
# Out:
# ['P', 'h', 'n', 'o', 't', 'y']

# %%
print(*sorted("Python"), sep = "")
# Out:
# Phnoty

# %%
obj = "Python"
new_obj = "p" + obj[1:] # change string
print(new_obj)
print(obj)
# Out:
# python
# Python

# %%
for i in dir(""):
    if "_" not in i:
        print(i)
# Out:
# capitalize
# casefold
# center
# count
# encode
# endswith
# expandtabs
# find
# format
# index
# isalnum
# isalpha
# isascii
# isdecimal
# isdigit
# isidentifier
# islower
# isnumeric
# isprintable
# isspace
# istitle
# isupper
# join
# ljust
# lower
# lstrip
# maketrans
# partition
# removeprefix
# removesuffix
# replace
# rfind
# rindex
# rjust
# rpartition
# rsplit
# rstrip
# split
# splitlines
# startswith
# strip
# swapcase
# title
# translate
# upper
# zfill

# %%
print(*enumerate("Python"))
# Out:
# (0, 'P') (1, 'y') (2, 't') (3, 'h') (4, 'o') (5, 'n')

# %%
for i in enumerate("Python"):
    print(i, end = "")
# Out:
# (0, 'P')(1, 'y')(2, 't')(3, 'h')(4, 'o')(5, 'n')

# %%
for i,j in enumerate("Python"):
    print("Index: ",i, " Char: ", j)
# Out:
# Index:  0  Char:  P
# Index:  1  Char:  y
# Index:  2  Char:  t
# Index:  3  Char:  h
# Index:  4  Char:  o
# Index:  5  Char:  n

# %%
for order, method in enumerate(dir("")):
    if "_" not in method:
        print(order, method)
# Out:
# 33 capitalize
# 34 casefold
# 35 center
# 36 count
# 37 encode
# 38 endswith
# 39 expandtabs
# 40 find
# 41 format
# 43 index
# 44 isalnum
# 45 isalpha
# 46 isascii
# 47 isdecimal
# 48 isdigit
# 49 isidentifier
# 50 islower
# 51 isnumeric
# 52 isprintable
# 53 isspace
# 54 istitle
# 55 isupper
# 56 join
# 57 ljust
# 58 lower
# 59 lstrip
# 60 maketrans
# 61 partition
# 62 removeprefix
# 63 removesuffix
# 64 replace
# 65 rfind
# 66 rindex
# 67 rjust
# 68 rpartition
# 69 rsplit
# 70 rstrip
# 71 split
# 72 splitlines
# 73 startswith
# 74 strip
# 75 swapcase
# 76 title
# 77 translate
# 78 upper
# 79 zfill

# %%
for order, method in enumerate(dir(""), start=-33):
    if "_" not in method:
        print(order, method)
# Out:
# 0 capitalize
# 1 casefold
# 2 center
# 3 count
# 4 encode
# 5 endswith
# 6 expandtabs
# 7 find
# 8 format
# 10 index
# 11 isalnum
# 12 isalpha
# 13 isascii
# 14 isdecimal
# 15 isdigit
# 16 isidentifier
# 17 islower
# 18 isnumeric
# 19 isprintable
# 20 isspace
# 21 istitle
# 22 isupper
# 23 join
# 24 ljust
# 25 lower
# 26 lstrip
# 27 maketrans
# 28 partition
# 29 removeprefix
# 30 removesuffix
# 31 replace
# 32 rfind
# 33 rindex
# 34 rjust
# 35 rpartition
# 36 rsplit
# 37 rstrip
# 38 split
# 39 splitlines
# 40 startswith
# 41 strip
# 42 swapcase
# 43 title
# 44 translate
# 45 upper
# 46 zfill

# %%
"pyhton".replace("p", "P")
# Out:
# 'Pyhton'

# %%
obj = "Try"
obj.replace("T", "t")
# Out:
# 'try'

# %%
"python".replace("p", "ch")
# Out:
# 'chython'

# %%
obj = "Python Programming Language is very easy."
obj.replace(" ", "",2)
# Out:
# 'PythonProgrammingLanguage is very easy.'
