# %% [markdown]
# # If-Elif-Else

# %% [markdown]
# ## If Condition

# %%
num = 34
if (num>30):
    print("Num is bigger than 30.")
# Out:
# Num is bigger than 30.

# %%
num = int(input("Number:"))
if(num>10):
    print("Num is bigger than 10.")
if(num<10):
    print("Num is smaller than 10.")
if(num == 10):
    print("Num is 10.")
# Out:
# Number: 10
# Num is 10.

# %%
password = "4512351"
user_pas = input("Please input password:")
if(user_pas == password):
    print("Welcome!!!")
if(user_pas!=password):
    print("Wrong password!!")
# Out:
# Please input password: 141231
# Wrong password!!

# %%
num = int(input("Number:"))
if(num<100):
    print("Num is smaller than 100.")
if(num<50):
    print("Num is smaller than 50.")
if(num == 100):
    print("Num is 100.")
if(num>0):
    print("Num is positive.")
# Out:
# Number: 100
# Num is 100.
# Num is positive.

# %%
num = int(input("Number:"))
if(num<100):
    print("Num is smaller than 100.")
if(num<50):
    print("Num is smaller than 50.")
if(num == 100):
    print("Num is 100.")
if(num>0):
    print("Num is positive.")
# Out:
# Number: 75
# Num is smaller than 100.
# Num is positive.

# %%
num = int(input("Number:"))
if(num<100):
    print("Num is smaller than 100.")
if(num<50):
    print("Num is smaller than 50.")
if(num == 100):
    print("Num is 100.")
if(num>0):
    print("Num is positive.")
# Out:
# Number: 49
# Num is smaller than 100.
# Num is smaller than 50.
# Num is positive.

# %%
num = int(input("Number:"))
if(num<100):
    print("Num is smaller than 100.")
if(num<50):
    print("Num is smaller than 50.")
if(num == 100):
    print("Num is 100.")
if(num>0):
    print("Num is positive.")
# Out:
# Number: -1
# Num is smaller than 100.
# Num is smaller than 50.

# %% [markdown]
# ## If - Elif Condition

# %%
num = int(input("Number:"))
if(num==100):
    print("Num is 100.")
elif(num<50):
    print("Num is smaller than 50.")
elif(num < 100):
    print("Num is smaller than 100.")
elif(num>0):
    print("Num is positive.")
elif (num<0):
    print("Num is negative")
# Out:
# Number: 100
# Num is 100.

# %%
num = int(input("Number:"))
if(num==100):
    print("Num is 100.")
elif(num<50):
    print("Num is smaller than 50.")
elif(num < 100):
    print("Num is smaller than 100.")
elif(num>0):
    print("Num is positive.")
elif (num<0):
    print("Num is negative")
# Out:
# Number: 39
# Num is smaller than 50.

# %%
num = int(input("Number:"))
if(num==100):
    print("Num is 100.")
elif(num<50):
    print("Num is smaller than 50.")
elif(num < 100):
    print("Num is smaller than 100.")
elif(num>0):
    print("Num is positive.")
elif (num<0):
    print("Num is negative")
# Out:
# Number: 102
# Num is positive.

# %%
num = int(input("Number:"))
if(num>0):
    print("Number is positive.")
elif(num<0):
    print("Number is negative.")
# Out:
# Number: 45
# Number is positive.

# %%
num = int(input("Number:"))
if(num>0):
    print("Number is positive.")
elif(num<0):
    print("Number is negative.")
# Out:
# Number: -3
# Number is negative.

# %%
num = int(input("Number:"))
if(num>0):
    print("Number is positive.")
elif(num<0):
    print("Number is negative.")
# Out:
# Number: 0

# %% [markdown]
# ## If-Elif-Else

# %%
num = int(input("Number:"))
if(num>0):
    print("Number is positive.")
elif(num<0):
    print("Number is negative.")
else:
    print("Number is zero.")
# Out:
# Number: 0
# Number is zero.

# %%
number = 10
if(number>10):
    print("Run the first condition.")
if(number<10):
    print("Run the second condition.")
if(number == 10):
    print("Run the third condition.")

else:
    print("Run the last condition.")
# Out:
# Run the third condition.

# %%
number = 12
if(number>10):
    print("Run the first condition.")
if(number<10):
    print("Run the second condition.")
if(number == 10):
    print("Run the third condition.")

else:
    print("Run the last condition.")
# Out:
# Run the first condition.
# Run the last condition.

# %%
number = 9
if(number>10):
    print("Run the first condition.")
if(number<10):
    print("Run the second condition.")
if(number == 10):
    print("Run the third condition.")

else:
    print("Run the last condition.")
# Out:
# Run the second condition.
# Run the last condition.
